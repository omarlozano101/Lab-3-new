# %%
import numpy as np

# curve-fit() function imported from scipy
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
from scipy import stats


y = [1,2,3,4,5,6] # Meters
x = [3.5E-9, 3.6E-9, 7.3E-9, 10.6E-9, 13.6E-9, 17.6E-9] #rising edges

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("Slope is ", slope)
print("Intercept is ", intercept)
print("R value is ", r_value)
print("P value is ", p_value)
print("Standard Error is ", std_err)
#plt.plot(x,y,  'o', label='original data')
plt.plot(x, [intercept + slope * n for n in x], 'r', label='fitted line')
plt.errorbar(x,y,yerr=[1.5, 0.5, 0.2, 0.2,0.1,0.2], fmt = 'o')
plt.title("Linear Fit of Falling Edge")
plt.ylabel("Distance")
plt.xlabel("Time")
plt.legend()
plt.show()
# Out:
# Slope is  326059641.48098505
# Intercept is  0.44590802479477354
# R value is  0.9833614476554567
# P value is  0.0004129590159199622
# Standard Error is  30117060.08355451

# %%
import numpy as np

# curve-fit() function imported from scipy
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
from scipy import stats


y = [1,2,3,4,5,6,1,2,3,4,5,6] # Meters
x = [3.5E-9, 3.6E-9, 7.3E-9, 10.6E-9, 13.6E-9, 17.6E-9,0.6E-9, 4.4E-9, 7.3E-9, 10.6E-9,13.8E-9,17.6E-9] #rising edges

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("Slope is ", slope)
print("Intercept is ", intercept)
print("R value is ", r_value)
print("P value is ", p_value)
print("Standard Error is ", std_err)
#plt.plot(x,y,  'o', label='original data')
plt.plot(x, [intercept + slope * n for n in x], 'r', label='fitted line')
plt.errorbar(x,y,yerr=[1.5, 0.5, 0.2, 0.2,0.1,0.2,1.5,0.5,0.2,0.2,0.1,0.2], fmt = 'o')
plt.title("Linear Fit of Falling Edge")
plt.ylabel("Distance")
plt.xlabel("Time")
plt.legend()
plt.show()
# Out:
# Slope is  311484488.2233036
# Intercept is  0.631747004277079
# R value is  0.9900940269604541
# P value is  7.388436237344481e-10
# Standard Error is  13968357.843001327

# %%
import numpy as np

# curve-fit() function imported from scipy
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
from scipy import stats


y = [4, 5, 5, 6, 6] # Meters
x = [12.8E-9, 12E-9, 13.5E-9, 12.6E-9, 16E-9] #rising edges

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("Slope is ", slope)
print("Intercept is ", intercept)
print("R value is ", r_value)
print("P value is ", p_value)
print("Standard Error is ", std_err)
#plt.plot(x,y,  'o', label='original data')
plt.plot(x, [intercept + slope * n for n in x], 'r', label='fitted line')
plt.errorbar(x,y,yerr=[2.6, 4.3, 5.3, 2.6, 0.3], fmt = 'o')
plt.title("Linear Fit of Falling Edge with Pipe")
plt.ylabel("Distance")
plt.xlabel("Time")
plt.legend()
plt.show()
# Out:
# Slope is  248766447.36842096
# Intercept is  1.8715049342105279
# R value is  0.4636866254855054
# P value is  0.4315127504060185
# Standard Error is  274435300.2270392

# %%
import numpy as np

# curve-fit() function imported from scipy
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt
from scipy import stats


y = [4,5,6] # Meters
x = [15.6E-9, 17.1E-9, 22E-9] #rising edges

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print("Slope is ", slope)
print("Intercept is ", intercept)
print("R value is ", r_value)
print("P value is ", p_value)
print("Standard Error is ", std_err)
#plt.plot(x,y,  'o', label='original data')
plt.plot(x, [intercept + slope * n for n in x], 'r', label='fitted line')
plt.errorbar(x,y,yerr=[1.5, 2.5, 0.9], fmt = 'o')
plt.title("Linear Fit of Falling Edge with water in Pipe")
plt.ylabel("Distance")
plt.xlabel("Time")
plt.legend()
plt.show()
# Out:
# Slope is  285629277.00089276
# Intercept is  -0.20797381731627862
# R value is  0.9560406301004453
# P value is  0.18946315812070255
# Standard Error is  87607449.35635497
